# %%
import pandas as pd
import yfinance as yf

ticker = yf.Ticker("BTC-USD")
df = ticker.history(period="max")
ticker.info
# Out:
# {'companyOfficers': [],
#  'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,900,334. The last known price of Bitcoin is 114,453.04360961 USD and is down -3.34 over the last 24 hours. It is currently trading on 12273 active market(s) with $85,611,854,654.90 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 113266.37,
#  'open': 113266.37,
#  'dayLow': 113193.93,
#  'dayHigh': 114005.17,
#  'regularMarketPreviousClose': 113266.37,
#  'regularMarketOpen': 113266.37,
#  'regularMarketDayLow': 113193.93,
#  'regularMarketDayHigh': 114005.17,
#  'volume': 73051086848,
#  'regularMarketVolume': 73051086848,
#  'averageVolume': 54531971242,
#  'averageVolume10days': 69850516668,
# ...

# %%
df
# Out:
#                                     Open           High            Low  \
# Date
# 2014-09-17 00:00:00+00:00     465.864014     468.174011     452.421997
# 2014-09-18 00:00:00+00:00     456.859985     456.859985     413.104004
# 2014-09-19 00:00:00+00:00     424.102997     427.834991     384.532013
# 2014-09-20 00:00:00+00:00     394.673004     423.295990     389.882996
# 2014-09-21 00:00:00+00:00     408.084991     412.425995     393.181000
# ...                                  ...            ...            ...
# 2025-07-28 00:00:00+00:00  119457.523438  119819.789062  117441.437500
# 2025-07-29 00:00:00+00:00  117938.585938  119273.867188  116987.367188
# 2025-07-30 00:00:00+00:00  117921.992188  118780.726562  115800.828125
# 2025-07-31 00:00:00+00:00  117833.632812  118919.984375  115505.218750
# 2025-08-02 00:00:00+00:00  113266.367188  114005.171875  113193.929688
#
#                                    Close       Volume  Dividends  Stock Splits
# Date
# ...
